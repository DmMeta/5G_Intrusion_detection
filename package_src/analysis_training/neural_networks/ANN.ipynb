# %%
# General Imports
import pandas as pd
import seaborn as sns
from math import ceil
from sklearn.preprocessing import LabelEncoder, StandardScaler, OrdinalEncoder
from sklearn.feature_selection import f_classif
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from time import perf_counter as time
import numpy as np
import random as rnd
from sklearn.impute import SimpleImputer
from sklearn.metrics import (accuracy_score, confusion_matrix, classification_report, accuracy_score, 
                             make_scorer, recall_score, f1_score, precision_score)
from sklearn.model_selection import StratifiedKFold
import os
from analysis_training.preprocessing_utils import drop_features_, fill_nan_values
import analysis_training
import analysis_training.neural_networks.model_definition as models
import analysis_training.neural_networks.nn_utils as nn_utils
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# ### The code reads a compressed CSV dataset from a specified file path using pandas. It focuses on preparing the dataset for classification tasks by setting the target variable, removing irrelevant features and providing key insights such as the dataset's shape, information and the count of NULL & unique values per column.
# ***Tasks***:
# - Reads a compressed CSV dataset using pandas.
# - Defines the target variable for either multi-class or binary classification.
# - Removes irrelevant features from the dataset.
# - Prints the original shape of the dataset.
# - Displays dataset information, including data types.
# - Prints the number of NULL values per column.
# - Prints the number of unique values per column.

# %%
# dataset_fpath = '../../data/BTS1_BTS2_fields_preserved.zip'
nidd_dataset = analysis_training.load_dataset()

# Attack Type for Multi-Class Classification or Label for Binary Classification
TARGET = 'Label'
DROPPED_TARGET = "Label" if TARGET == "Attack Type" else "Attack Type"

useless_features = ['Attack Tool', DROPPED_TARGET, 'Dport', 'Sport', 'SrcAddr', 'DstAddr',"Unnamed: 0"]
nidd_dataset = nidd_dataset.drop(useless_features, axis=1)
print(f"Original shape of Dataset: {nidd_dataset.shape}")

print(f'\nDataset Information:')
nidd_dataset.info()

# print(f'\nDataset Description:')
# print(nidd_dataset.describe())

print(f'\nNumber of NULL values per column:')
print(nidd_dataset.isnull().sum())

print(f'\nNumber of unique values per column:')
print(nidd_dataset.nunique())

plt.figure(figsize=(5, 4))
ax = sns.countplot(x=TARGET, data=nidd_dataset)
total_count = len(nidd_dataset)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_count)
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='bottom')

plt.title(f'Distribution of {TARGET} variable')
plt.xlabel(TARGET)
plt.ylabel('Count')
plt.show()
# Out:
# Original shape of Dataset: (1215890, 106)
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1215890 entries, 0 to 1215889
# Columns: 106 entries, SrcId to Label
# dtypes: float64(66), int64(24), object(16)
# memory usage: 983.3+ MB
#
# Number of NULL values per column:
# SrcId             0
# Rank              0
# StartTime         0
# LastTime          0
# Trans             0
#               ...
# TcpRtt            0
# SynAck            0
# AckDat            0
# TcpOpt       938654
# Label             0
# Length: 106, dtype: int64
#
# Number of unique values per column:
# SrcId             1
# Rank         467717
# StartTime     32888
# LastTime      32828
# Trans             1
#               ...
# TcpRtt        18745
# SynAck         3896
# AckDat        23870
# TcpOpt            7
# Label             2
# Length: 106, dtype: int64

# %% [markdown]
# ### Dropping columns based on specified threshold values
# ***Tasks***:
# - Initializes dictionaries to store dropped features and processing time.
# - Drops columns with more than 95% NaN values from the dataset.
# - Drops columns with more than 95% zero values from the updated dataset.
# - Drops constant columns from the further cleaned dataset.
# - Calculates and prints the time taken for the dropping features step.

# %%
# Dictionary to store dropped features based on different criteria
features_dropped = {"Nan columns": [], "Zero columns": [], "Constant columns": [], "General columns": useless_features}

# Dictionary to store processing time
preprocessing_d = {"Time <Dropping features based on a threshold `bad` values>": 0.,
                   "Time <Filling NaNs>": 0.,
                   "Time <Encoding categorical features>": 0.,
                   "Time <Feature selection>": 0.,
                   "Time <Data preprocessing>": 0.,
                   "Time <Model training>": 0.,
                   "Time <Model testing>": 0.,
                   "Time <K-Fold cross validation>": 0.,}

# Record the starting time for dropping features based on "bad" values
t0 = time()

# Dropping columns with more than 95% NaN values
threshold_nans = 0.95 * nidd_dataset.shape[0]
columns_Nan_to_drop = nidd_dataset.columns[nidd_dataset.isna().sum() > threshold_nans]
features_dropped["Nan columns"].extend(columns_Nan_to_drop)
nidd_dataset_cleaned_nan = nidd_dataset.drop(columns=columns_Nan_to_drop)
# Alternatively, you can use:
# nidd_dataset_cleaned_nan = nidd_dataset.dropna(thresh=ceil(1 - threshold_nans), axis=1)
print(f"After dropping NaN columns: {nidd_dataset_cleaned_nan.shape}")

# Dropping columns with more than 95% zero values
threshold_zeros = 0.95 * nidd_dataset.shape[0]
zero_counts = nidd_dataset_cleaned_nan.apply(lambda col: (col == 0).sum())
columns_zeros_to_drop = zero_counts[zero_counts > threshold_zeros].index
features_dropped["Zero columns"].extend(columns_zeros_to_drop)
nidd_dataset_cleaned_zeros = nidd_dataset_cleaned_nan.drop(columns_zeros_to_drop, axis=1)
print(f"After dropping NaN & Zero columns: {nidd_dataset_cleaned_zeros.shape}")

# Dropping constant columns
constant_columns = nidd_dataset_cleaned_zeros.columns[nidd_dataset_cleaned_zeros.nunique() == 1]
features_dropped["Constant columns"].extend(constant_columns)
nidd_dataset_cleaned = nidd_dataset_cleaned_zeros.drop(columns=constant_columns)
print(f"After dropping NaN & Zero & Constant columns: {nidd_dataset_cleaned.shape}")

# Record the ending time for dropping features based on "bad" values
t1 = time()

# Calculate and print the time taken for the dropping features step
preprocessing_d["Time <Dropping features based on a threshold `bad` values>"] = t1 - t0
print(f"Time <Dropping features based on a threshold `bad` values>: {preprocessing_d['Time <Dropping features based on a threshold `bad` values>']:.3f} seconds")

# equivalent
# nidd_dataset_cleaned, drop_time = drop_features_(nidd_dataset,[0.95, 0.95], features_dropped)
# preprocessing_d["Time <Dropping features based on a threshold `bad` values>"] = drop_time
# print(f"Time <Dropping features based on a threshold `bad` values>: {preprocessing_d['Time <Dropping features based on a threshold `bad` values>']:.3f} seconds")
# Out:
# After dropping NaN columns: (1215890, 70)
# After dropping NaN & Zero columns: (1215890, 55)
# After dropping NaN & Zero & Constant columns: (1215890, 51)
# Time <Dropping features based on a threshold `bad` values>: 2.638 seconds

# %% [markdown]
# ### Filling NaN values and Encoding categorical columns using Label Encoder
# ***Tasks***:
#
# **1. Filling NaN Values:**
#    - Identify numeric and categorical columns in the cleaned dataset.
#    - Fill NaN values in numeric columns with the mean of each column.
#    - Fill NaN values in categorical columns with the mode of each column.
#    - Print the time taken for filling NaN values.
#
# **2. Encoding Categorical Features:**
#    - Use LabelEncoder to transform categorical columns into numerical representations.
#    - Print the time taken for encoding categorical features.

# %%
# Record the starting time for filling NaN values
t0 = time()

# Get numeric and categorical columns
numeric_cols = nidd_dataset_cleaned.select_dtypes(include='number').columns
categorical_cols = nidd_dataset_cleaned.select_dtypes(include='object').columns

# Fill NaN values in numeric columns with mean
numeric_cols_mean = nidd_dataset_cleaned[numeric_cols].mean()
nidd_dataset_cleaned[numeric_cols] = nidd_dataset_cleaned[numeric_cols].fillna(numeric_cols_mean)

# Fill NaN values in categorical columns with mode
# iloc[0] is used to get the first element of the series in case there is more than one mode.
categorical_cols_mode = nidd_dataset_cleaned[categorical_cols].mode().iloc[0]
nidd_dataset_cleaned[categorical_cols] = nidd_dataset_cleaned[categorical_cols].fillna(categorical_cols_mode)

# Record the ending time for filling NaN values
t1 = time()
preprocessing_d["Time <Filling NaNs>"] = t1 - t0

# Print the time taken for filling NaN values
print(f"Time <Filling NaNs>: {preprocessing_d['Time <Filling NaNs>']:.3f} seconds")

# equivalent
# nidd_dataset_cleaned, fill_time = fill_nan_values(nidd_dataset_cleaned, method = "mean")
# preprocessing_d["Filling NaNs"] = fill_time
# print(f"Time <Filling NaNs>: {preprocessing_d['Time <Filling NaNs>']:.3f} seconds")

# Record the starting time for encoding categorical features
t0 = time()

# Encoding categorical columns using LabelEncoder
label_encoder = LabelEncoder()
for column in categorical_cols:
    nidd_dataset_cleaned[column] = label_encoder.fit_transform(nidd_dataset_cleaned[column])

# Record the ending time for encoding categorical features
t1 = time()
preprocessing_d["Time <Encoding categorical features>"] = t1 - t0

# Print the time taken for encoding categorical features
print(f"Time <Encoding categorical features>: {preprocessing_d['Time <Encoding categorical features>']:.3f} seconds")
# Out:
# Time <Filling NaNs>: 2.612 seconds
# Time <Encoding categorical features>: 1.387 seconds

# %% [markdown]
# ### Dropping features based on the Pearson Correlation Matrix
#
# ***Tasks***:
# - Define the target column for correlation analysis (e.g. TARGET).
# - Calculate the correlation matrix using the Pearson method.
# - Set a correlation threshold for feature selection (e.g. 0.9).
# - Identify pairs of features with high correlation.
# - Initialize a set to store features to be dropped (avoiding duplicates).
# - Iterate through the pairs of highly correlated features.
#    - Check if the correlation signs are the same.
#    - Keep the feature with the higher absolute correlation with the target variable.
#    - Add the selected feature to the set of features to be dropped.
# - Drop the identified features with high correlation from the cleaned dataset.
# - Update the total preprocessing time for feature selection.
# - Print the final shape of the cleaned DataFrame after removing correlated features.
# - Visualize the correlation matrix with a heatmap.

# %%
t0 = time()

# Define the target column for correlation analysis
target_col = nidd_dataset_cleaned.columns[-1] # eq: TARGET

# Calculate the correlation matrix using Pearson method
correlation_matrix = nidd_dataset_cleaned.corr(method='pearson')

# Set the correlation threshold for feature selection
corr_threshold = 0.9

# Identify pairs of features with high correlation
high_corr_pairs = correlation_matrix.iloc[:, :-1].abs() > corr_threshold

# Initialize a set to store features to be dropped (avoiding duplicates)
features_to_drop = set()

# Iterate through the pairs of highly correlated features
for feature_on_col in high_corr_pairs.columns:
    for feature_in_row in high_corr_pairs.index[high_corr_pairs[feature_on_col]]:
        if feature_on_col != feature_in_row:  # Avoid comparisons between the same pairs
            # Get the correlation values for each feature against the target variable
            feature_in_row_cor_val = correlation_matrix.loc[feature_in_row, target_col]
            feature_on_col_cor_val = correlation_matrix.loc[feature_on_col, target_col]
            
            # Check if the correlation signs are the same
            same_corellation_sign = feature_in_row_cor_val * feature_on_col_cor_val > 0
            
            # If the signs are the same, keep the feature with the higher absolute correlation
            if same_corellation_sign:
                if abs(feature_in_row_cor_val) > abs(feature_on_col_cor_val):
                    features_to_drop.add(feature_on_col)
                else:
                    features_to_drop.add(feature_in_row)

# Drop the identified features with high correlation
nidd_dataset_filtered = nidd_dataset_cleaned.drop(columns=list(features_to_drop))

t1 = time()

# Update the total preprocessing time for feature selection
preprocessing_d["Time <Feature selection>"] += t1 - t0

# Print the final shape of the cleaned DataFrame after removing correlated features
print(f"Final shape of cleaned DataFrame after removing correlated features based on Pearson method: {nidd_dataset_filtered.shape}")

# Visualize the correlation matrix with a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', 
            fmt='.2f', xticklabels=False, yticklabels=False,
            linewidths=.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# Final shape of cleaned DataFrame after removing correlated features based on Pearson method: (1215890, 36)

# %% [markdown]
# ### ANOVA F-scores are calculated for each feature and a DataFrame is created to store feature names & their corresponding F-scores. The top features are then selected based on the highest F-scores.
# ***Tasks***:
# - Separate features (X) and the target variable (y) from the filtered dataset.
# - Calculate ANOVA F-scores for each feature.
# - Create a DataFrame to store feature names and their corresponding F-scores.
# - Sort the DataFrame based on F-scores in descending order.
# - Select the top 10 features based on ANOVA F-scores.
# - Print the top 10 features and their corresponding F-scores.
# - Print the time taken for feature selection.

# %%
# Separate features (X) and target variable (y)
X = nidd_dataset_filtered.drop(columns=[target_col])
y = nidd_dataset_filtered[target_col]

# Record the starting time for ANOVA F-score feature selection
t0 = time()

# Calculate ANOVA F-scores
f_scores, _ = f_classif(X, y)
# Create a DataFrame to store feature names and their corresponding F-scores
results_df = pd.DataFrame({'Feature': X.columns, 'F-Score': f_scores})
# Sort the DataFrame based on F-scores in descending order
results_df = results_df.sort_values(by='F-Score', ascending=False)

# Record the ending time for ANOVA F-score feature selection
t1 = time()
preprocessing_d["Time <Feature selection>"] += t1-t0

# Select the top 10 features based on ANOVA F-scores
top_10_features = results_df.head(10)

# Print the top 10 features and their corresponding F-scores
print("Top 10 Features based on ANOVA F-scores:")
for index, row in top_10_features.iterrows():
    print(f"{row['Feature']}: {row['F-Score']}")

# Print the time taken for feature selection
print(f"\nTime <Feature selection>: {preprocessing_d['Time <Feature selection>']:.3f} seconds")
# Out:
# Top 10 Features based on ANOVA F-scores:
# Seq: 469849.6390666038
# Offset: 319314.40971959295
# sTtl: 271902.447512305
# AckDat: 114843.30885848559
# Dir: 67629.15152188136
# StartTime: 54826.22943189787
# dIpId: 53749.31118614725
# TcpRtt: 48169.83238437568
# dTtl: 40155.94625566492
# sMeanPktSz: 38473.44797186211
#
# Time <Feature selection>: 7.763 seconds

# %% [markdown]
# ### Applying Z-Normalization to the selected numerical features. Using Ordinal Encoder to transform categorical columns into numerical representations and Label Endoder to tranform target categorical column into numerical representation. Creating an appropriate pipeline that includes the appropriate preprocessors(e.g. SimpleImputer, StandardScaler) and fitting - transform the pipeline on the dataset.
# ***Tasks***:
# - Extract the top 10 feature columns from the DataFrame based on ANOVA F-scores.
# - Extract the target variable and feature values from the original dataset based on the top 10 features.
# - Split the dataset into training and testing sets.
# - Identify numeric and categorical features within the top 10 features.
# - Create transformers for numeric and categorical features, including imputation and scaling for numeric features and imputation and encoding for categorical features.
# - Create a ColumnTransformer to apply different transformers to numeric and categorical features.
# - Create a pipeline(that includes preprocessing) in which the input data is fitted and transformed.
# - Record the starting time for preprocessing the input data.
# - Fit - Transform the pipeline on the dataset(input data).
# - Fit - Transform the Label Encoder on the target categorical column.
# - Print the time taken for data preprocessing.

# %%
# Extract top 10 feature columns from the DataFrame
top_10_features_cols = top_10_features['Feature'].tolist()
# top_10_features_cols = ['Seq','Offset','sTtl','AckDat','Dir','StartTime','dIpId','TcpRtt','dTtl','sMeanPktSz']

# Extract target variable and features' values based on top 10 features
target = nidd_dataset[TARGET]
features = nidd_dataset[top_10_features_cols]

# Identify numeric and categorical features within the top 10 features
numeric_features = list(set(numeric_cols) & set(top_10_features_cols))  # Numeric features
categorical_features = list(set(categorical_cols) & set(top_10_features_cols))  # Categorical features

# Create transformers for numeric and categorical features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),  # Imputation using mean
    ('scaler', StandardScaler())  # Standard scaling
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),  # Imputation using most frequent value
    ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=np.nan))  # Ordinal encoding
])

# Create a ColumnTransformer to apply different transformers to numeric and categorical features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),  # Apply numeric transformer to numeric features
        ('cat', categorical_transformer, categorical_features)  # Apply categorical transformer to categorical features
    ])

pipeline = Pipeline([
    ('preprocessor', preprocessor)  # Include data preprocessing in the pipeline
])

t0 = time()  # Record starting time for data preprocessing

# Fit and transform the dataset
transformed_dataset = pipeline.fit_transform(features)

# Encode the target variable
label_encoder = LabelEncoder()
encoded_target = label_encoder.fit_transform(target)

t1 = time()  # Record ending time for preprocessing
preprocessing_d["Time <Data preprocessing>"] = t1-t0  # Record the time taken for preprocessing

# Print the time taken for preprocessing
print(f"\nTime <Data preprocessing>: {preprocessing_d['Time <Data preprocessing>']:.3f} seconds")
# Out:
# Time <Data preprocessing>: 1.367 seconds

# %%
# import joblib
# with open('../../../models/ANN/ANN_preprocessor.pkl', 'rb') as file:
#     # Load the preprocessor using joblib
#     preprocessor = joblib.load(file)

# # Reconstruct the pipeline with the loaded preprocessor
# loaded_pipeline = Pipeline([
#     ('preprocessor', preprocessor),
#     # Add other steps if necessary, such as the estimator
# ])
# transformed_dataset = loaded_pipeline.fit_transform(features)

import joblib
with open('../../../models/ANN/ANN_preprocessor.pkl', 'wb') as file:
     joblib.dump(pipeline, file)

# with open('../../../models/LabelEncoder.pkl', 'wb') as file:
# #     # Load the preprocessor using joblib
#      joblib.dump(label_encoder, file)

# enc_target = lab_enc.fit_transform(target)

# %% [markdown]
# ### Training - Testing ANN Binary Classifier
# ***Tasks***:
# 1. Data Preprocessing:
# - The dataset is preprocessed to be compatible with PyTorch. The input features (X_tensor) and the target labels (y_tensor) are converted into PyTorch tensors. The dataset is then split into training and testing sets using the train_test_split function from scikit-learn. These sets are further converted into PyTorch TensorDataset objects for easier handling during training and testing.
#
# 2. Model Definition and Optimization:
# - The neural network model is defined using the ANN_BinaryClassifier class. The model architecture consists of an input layer, a hidden layer with a specified size (hidden_size) and an output layer with a single neuron for binary classification. The loss function used is binary cross-entropy loss (BCELoss). Also, the Adam optimizer is used for training.
#
# 3. Training Loop:
# - The training loop iterates over a specified number of epochs. Within each epoch, the model is set to training mode (model.train()) and the training dataset is iterated over in batches using the train_loader. For each batch, the model computes the output predictions, calculates the loss using binary cross-entropy, performs backpropagation to update the model parameters and calculates the training accuracy.
#
# 4. Testing Loop:
# - After training, the model is evaluated on the testing dataset. The model is set to evaluation mode (model.eval()) and the testing dataset is iterated over in batches using the test_loader. During testing, gradient calculation is disabled (torch.no_grad()) to save computational resources. The model predictions are compared with the true labels to calculate the testing accuracy.
#
# 5. Performance Metrics Logging:
# - Throughout training and testing, the code logs the training and testing losses, as well as the training and testing accuracies, for each epoch. These metrics are typically used to monitor the performance of the model and assess its convergence and generalization capabilities.

# %%
X_tensor = torch.FloatTensor(transformed_dataset)
y_tensor = torch.FloatTensor(encoded_target).unsqueeze(1)  # Add an extra dimension for binary classification

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_tensor, y_tensor, test_size=0.2, random_state=rnd.seed(42))

# Create PyTorch datasets and data loaders
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Define model parameters
input_size = X_train.shape[1]
hidden_size = 8
output_size = 1  
learning_rate = 0.001
num_epochs = 50

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

# Initialize the model loss function and optimizer
model = models.ANN_BinaryClassifier(input_size, hidden_size, output_size).to(device) # Initialize the model and move it to the GPU
criterion = nn.BCELoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

score_funcs = {'Accuracy': accuracy_score, 'Recall': recall_score, 'Precision': precision_score, 'F1': f1_score}

training = nn_utils.Training(model = model, optimizer = optimizer, loss_fn = criterion, device = device, score_funcs = score_funcs)
training.train(train_loader = train_loader, test_loader = test_loader, epochs = num_epochs)
results = training.results

# Calculate and print the time taken for training - testing the model
preprocessing_d["Time <Model training>"] = results['total training time']
preprocessing_d["Time <Model testing>"] = results['total testing time']
print(f"Time <Model training>: {preprocessing_d['Time <Model training>']:.3f} seconds")
print(f"Time <Model testing>: {preprocessing_d['Time <Model testing>']:.3f} seconds")
# Out:
# Device: cpu
# |train():71| - Training - Epoch [1/50], Loss: 38.9625, Accuracy: 59.98%
# |train():87| - Testing - Epoch [1/50], Loss: 39.3935, Accuracy: 60.55%
# |train():71| - Training - Epoch [2/50], Loss: 38.7645, Accuracy: 60.57%
# |train():87| - Testing - Epoch [2/50], Loss: 39.3985, Accuracy: 60.56%
# |train():71| - Training - Epoch [3/50], Loss: 38.6952, Accuracy: 60.68%
# |train():87| - Testing - Epoch [3/50], Loss: 39.2893, Accuracy: 60.60%
# |train():71| - Training - Epoch [4/50], Loss: 14.3863, Accuracy: 81.12%
# |train():87| - Testing - Epoch [4/50], Loss: 4.6969, Accuracy: 93.26%
# |train():71| - Training - Epoch [5/50], Loss: 4.4227, Accuracy: 91.13%
# |train():87| - Testing - Epoch [5/50], Loss: 3.7082, Accuracy: 94.09%
# |train():71| - Training - Epoch [6/50], Loss: 4.0106, Accuracy: 92.09%
# |train():87| - Testing - Epoch [6/50], Loss: 4.6272, Accuracy: 92.94%
# |train():71| - Training - Epoch [7/50], Loss: 3.6617, Accuracy: 93.00%
# |train():87| - Testing - Epoch [7/50], Loss: 3.7068, Accuracy: 94.28%
# |train():71| - Training - Epoch [8/50], Loss: 3.2638, Accuracy: 93.76%
# |train():87| - Testing - Epoch [8/50], Loss: 3.9773, Accuracy: 91.93%
# |train():71| - Training - Epoch [9/50], Loss: 2.4203, Accuracy: 94.82%
# |train():87| - Testing - Epoch [9/50], Loss: 1.6823, Accuracy: 97.34%
# |train():71| - Training - Epoch [10/50], Loss: 1.7076, Accuracy: 95.82%
# |train():87| - Testing - Epoch [10/50], Loss: 3.2248, Accuracy: 94.41%
# |train():71| - Training - Epoch [11/50], Loss: 1.1716, Accuracy: 96.49%
# |train():87| - Testing - Epoch [11/50], Loss: 2.6336, Accuracy: 93.87%
# |train():71| - Training - Epoch [12/50], Loss: 0.5175, Accuracy: 97.07%
# |train():87| - Testing - Epoch [12/50], Loss: 0.1682, Accuracy: 97.11%
# |train():71| - Training - Epoch [13/50], Loss: 0.2260, Accuracy: 97.56%
# |train():87| - Testing - Epoch [13/50], Loss: 0.0646, Accuracy: 98.83%
# |train():71| - Training - Epoch [14/50], Loss: 0.0968, Accuracy: 98.03%
# |train():87| - Testing - Epoch [14/50], Loss: 0.0851, Accuracy: 98.22%
# |train():71| - Training - Epoch [15/50], Loss: 0.0854, Accuracy: 98.18%
# |train():87| - Testing - Epoch [15/50], Loss: 0.0640, Accuracy: 98.06%
# |train():71| - Training - Epoch [16/50], Loss: 0.0794, Accuracy: 98.25%
# |train():87| - Testing - Epoch [16/50], Loss: 0.0796, Accuracy: 97.85%
# |train():71| - Training - Epoch [17/50], Loss: 0.0782, Accuracy: 98.34%
# |train():87| - Testing - Epoch [17/50], Loss: 0.0746, Accuracy: 97.72%
# |train():71| - Training - Epoch [18/50], Loss: 0.0756, Accuracy: 98.42%
# |train():87| - Testing - Epoch [18/50], Loss: 0.0700, Accuracy: 97.86%
# |train():71| - Training - Epoch [19/50], Loss: 0.0691, Accuracy: 98.47%
# |train():87| - Testing - Epoch [19/50], Loss: 0.0946, Accuracy: 98.05%
# |train():71| - Training - Epoch [20/50], Loss: 0.0675, Accuracy: 98.51%
# |train():87| - Testing - Epoch [20/50], Loss: 0.0548, Accuracy: 98.65%
# |train():71| - Training - Epoch [21/50], Loss: 0.0647, Accuracy: 98.57%
# |train():87| - Testing - Epoch [21/50], Loss: 0.0536, Accuracy: 99.03%
# |train():71| - Training - Epoch [22/50], Loss: 0.0645, Accuracy: 98.59%
# |train():87| - Testing - Epoch [22/50], Loss: 0.0463, Accuracy: 99.04%
# |train():71| - Training - Epoch [23/50], Loss: 0.0630, Accuracy: 98.61%
# |train():87| - Testing - Epoch [23/50], Loss: 0.0786, Accuracy: 97.63%
# |train():71| - Training - Epoch [24/50], Loss: 0.0627, Accuracy: 98.66%
# |train():87| - Testing - Epoch [24/50], Loss: 0.0490, Accuracy: 99.16%
# |train():71| - Training - Epoch [25/50], Loss: 0.0603, Accuracy: 98.67%
# |train():87| - Testing - Epoch [25/50], Loss: 0.0464, Accuracy: 99.23%
# |train():71| - Training - Epoch [26/50], Loss: 0.1152, Accuracy: 98.47%
# |train():87| - Testing - Epoch [26/50], Loss: 0.0770, Accuracy: 98.56%
# |train():71| - Training - Epoch [27/50], Loss: 0.0570, Accuracy: 98.71%
# |train():87| - Testing - Epoch [27/50], Loss: 0.0532, Accuracy: 98.32%
# |train():71| - Training - Epoch [28/50], Loss: 0.0574, Accuracy: 98.73%
# |train():87| - Testing - Epoch [28/50], Loss: 0.0555, Accuracy: 98.71%
# |train():71| - Training - Epoch [29/50], Loss: 0.0576, Accuracy: 98.75%
# |train():87| - Testing - Epoch [29/50], Loss: 0.0452, Accuracy: 99.26%
# |train():71| - Training - Epoch [30/50], Loss: 0.0548, Accuracy: 98.79%
# |train():87| - Testing - Epoch [30/50], Loss: 0.0946, Accuracy: 97.33%
# |train():71| - Training - Epoch [31/50], Loss: 0.0542, Accuracy: 98.79%
# |train():87| - Testing - Epoch [31/50], Loss: 0.0686, Accuracy: 98.22%
# |train():71| - Training - Epoch [32/50], Loss: 0.0550, Accuracy: 98.81%
# |train():87| - Testing - Epoch [32/50], Loss: 0.0718, Accuracy: 98.32%
# |train():71| - Training - Epoch [33/50], Loss: 0.0538, Accuracy: 98.81%
# |train():87| - Testing - Epoch [33/50], Loss: 0.0430, Accuracy: 98.28%
# |train():71| - Training - Epoch [34/50], Loss: 0.0605, Accuracy: 98.82%
# |train():87| - Testing - Epoch [34/50], Loss: 0.0612, Accuracy: 98.31%
# |train():71| - Training - Epoch [35/50], Loss: 0.0538, Accuracy: 98.84%
# |train():87| - Testing - Epoch [35/50], Loss: 0.0424, Accuracy: 99.04%
# |train():71| - Training - Epoch [36/50], Loss: 0.0521, Accuracy: 98.85%
# |train():87| - Testing - Epoch [36/50], Loss: 0.0383, Accuracy: 99.25%
# |train():71| - Training - Epoch [37/50], Loss: 0.0514, Accuracy: 98.85%
# |train():87| - Testing - Epoch [37/50], Loss: 0.0495, Accuracy: 98.82%
# |train():71| - Training - Epoch [38/50], Loss: 0.0536, Accuracy: 98.87%
# |train():87| - Testing - Epoch [38/50], Loss: 0.0399, Accuracy: 99.19%
# |train():71| - Training - Epoch [39/50], Loss: 0.0500, Accuracy: 98.87%
# |train():87| - Testing - Epoch [39/50], Loss: 0.0391, Accuracy: 99.31%
# |train():71| - Training - Epoch [40/50], Loss: 0.0512, Accuracy: 98.89%
# |train():87| - Testing - Epoch [40/50], Loss: 0.0602, Accuracy: 98.38%
# |train():71| - Training - Epoch [41/50], Loss: 0.0502, Accuracy: 98.91%
# |train():87| - Testing - Epoch [41/50], Loss: 0.0790, Accuracy: 97.51%
# |train():71| - Training - Epoch [42/50], Loss: 0.0499, Accuracy: 98.90%
# |train():87| - Testing - Epoch [42/50], Loss: 0.0345, Accuracy: 99.24%
# |train():71| - Training - Epoch [43/50], Loss: 0.0503, Accuracy: 98.89%
# |train():87| - Testing - Epoch [43/50], Loss: 0.0447, Accuracy: 98.36%
# |train():71| - Training - Epoch [44/50], Loss: 0.0532, Accuracy: 98.91%
# |train():87| - Testing - Epoch [44/50], Loss: 0.0361, Accuracy: 99.20%
# |train():71| - Training - Epoch [45/50], Loss: 0.0491, Accuracy: 98.92%
# |train():87| - Testing - Epoch [45/50], Loss: 0.0352, Accuracy: 99.32%
# |train():71| - Training - Epoch [46/50], Loss: 0.0488, Accuracy: 98.94%
# |train():87| - Testing - Epoch [46/50], Loss: 0.0506, Accuracy: 98.32%
# |train():71| - Training - Epoch [47/50], Loss: 0.0482, Accuracy: 98.94%
# |train():87| - Testing - Epoch [47/50], Loss: 0.0467, Accuracy: 98.18%
# |train():71| - Training - Epoch [48/50], Loss: 0.0474, Accuracy: 98.94%
# |train():87| - Testing - Epoch [48/50], Loss: 0.0375, Accuracy: 99.25%
# |train():71| - Training - Epoch [49/50], Loss: 0.0471, Accuracy: 98.95%
# |train():87| - Testing - Epoch [49/50], Loss: 0.0415, Accuracy: 98.73%
# |train():71| - Training - Epoch [50/50], Loss: 0.0472, Accuracy: 98.96%
# |train():87| - Testing - Epoch [50/50], Loss: 0.0560, Accuracy: 99.05%
# Time <Model training>: 890.355 seconds
# Time <Model testing>: 75.844 seconds

# %%
import joblib
with open("../../../models/ANN/ANN_model", "wb") as fp:
     joblib.dump(model.state_dict(), fp)
     
# import yaml
# with open('../../../src/config.yml', 'r') as file:
#     config_data = yaml.safe_load(file)

# config_data['NN']['ANN']['input_size'] = input_size
# config_data['NN']['ANN']['hidden_size'] = hidden_size
# config_data['NN']['ANN']['output_size'] = output_size

# with open('../../../src/config.yml', 'w') as file:
#     yaml.dump(config_data, file)

# %% [markdown]
# ### Confusion Matrix and Classification Report
# ***Tasks***:
# - Calculate the confusion matrix using the predicted and true labels from the test data.
# - Plot the confusion matrix using a heatmap for better visualization.
#    - Each cell represents the count of true positive instances, with text annotations.
# - Generate and print the classification report, including precision, recall and F1-score for each class in the target variable.

# %%
predictions = training.final_predictions

y_test = np.array(y_test, dtype = int)
predictions = np.array(predictions, dtype = int)

# Calculate the confusion matrix
conf_matrix = np.array(confusion_matrix(y_test, predictions))

# Get the unique categories in the target variable
target_categories = list(dict.fromkeys(nidd_dataset[TARGET]))

# Plot the confusion matrix
plt.figure(figsize=(6, 4))
plt.imshow(conf_matrix, cmap=plt.cm.Blues, interpolation='nearest')
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(ticks=np.arange(len(target_categories)), labels=target_categories, rotation=45)
plt.yticks(ticks=np.arange(len(target_categories)), labels=target_categories)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, format(conf_matrix[i, j], 'd'), ha="center", va="center", color="white" if conf_matrix[i, j] > conf_matrix.max() / 2 else "black")

plt.show()

# Generate and print the classification report
class_report = classification_report(predictions, y_test, target_names=target_categories, digits=6)
print("Classification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign   0.978771  0.997070  0.987836     94192
#    Malicious   0.998125  0.986328  0.992191    148986
#
#     accuracy                       0.990488    243178
#    macro avg   0.988448  0.991699  0.990013    243178
# weighted avg   0.990629  0.990488  0.990504    243178

# %% [markdown]
# ### ANN's Architecture and Computational Graph Visualization

# %%
from torchviz import make_dot

# Initialize the model
# model = ANN_BinaryClassifier(input_size, hidden_size, output_size)

# Perform a forward pass through the model to get the output
y = model(X_tensor[:1,:])

# Visualize the computational graph
make_dot(y.mean(), params=dict(model.named_parameters()))
# The `.mean()` function calculates the mean of the output tensor `y`, simplifying the visualization.
# make_dot(y.mean(), params=dict(model.named_parameters()), show_attrs=True, show_saved=True)

# %%
# Call the function to plot metrics
nn_utils.plot_metrics(results['train Accuracy'], results['train Loss'], results['test Accuracy'], results['test Loss'])
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Stratified K-Fold Cross-Validation Training and Evaluation Pipeline
#
# #### Steps:
# 1. **Data Preparation:**
#    - Convert input features and target labels from PyTorch tensors to NumPy arrays for compatibility with scikit-learn's cross-validation module.
#    - Define the number of splits for Stratified K-Fold cross-validation.
#
# 2. **Stratified K-Fold Cross-Validation:**
#    - Initialize Stratified K-Fold cross-validator with the specified number of splits.
#    - Iterate over each fold and split the data into training and validation sets.
#    - Create PyTorch datasets and data loaders for both training and validation sets.
#
# 3. **Model Training and Evaluation:**
#    - For each fold:
#      - Initialize the binary classification neural network model, loss function (Binary Cross-Entropy Loss) and optimizer (Adam).
#      - Perform the training loop over multiple epochs:
#        - Set the model to training mode.
#        - Iterate over batches in the training set, perform forward pass, compute loss, backpropagate gradients and update weights.
#        - Calculate training accuracy and loss for each epoch.
#      - Perform the validation loop over multiple epochs:
#        - Set the model to evaluation mode.
#        - Iterate over batches in the validation set, calculate validation loss and accuracy without updating weights.
#      - Store training and validation metrics for each fold.
#
# #### Output:
# - For each fold, the code prints training and validation metrics (loss and accuracy) for each epoch.
# - Additionally, it collects and stores these metrics for further analysis or visualization.
#
# #### Note:
# - This pipeline allows for robust evaluation of the model's performance across different folds, helping to mitigate overfitting and provide more reliable performance estimates.

# %%
# Convert tensors to NumPy arrays
X_numpy = X_tensor.numpy()
y_numpy = y_tensor.squeeze(1).numpy()  # Squeeze the extra dimension

# Define the number of splits for Stratified K-Fold cross-validation
num_splits = 5  

# Initialize Stratified K-Fold cross-validator
skf = StratifiedKFold(n_splits=num_splits, shuffle=True, random_state=42)

# Create dictionaries to store metrics for each fold
fold_metrics = {
    'train_loss': [],
    'val_loss': [],
    'train_accuracy': [],
    'val_accuracy': []
}


t0 = time() # Record the starting time for K-Fold cross-validation
# Iterate over folds
for fold, (train_indices, val_indices) in enumerate(skf.split(X_numpy, y_numpy)):
    
    print(f'\nFold {fold + 1}/{num_splits}')

    # Split data into training and validation sets
    X_train_fold, X_val_fold = torch.FloatTensor(X_numpy[train_indices]), torch.FloatTensor(X_numpy[val_indices])
    y_train_fold, y_val_fold = torch.FloatTensor(y_numpy[train_indices]).unsqueeze(1), torch.FloatTensor(y_numpy[val_indices]).unsqueeze(1)

    # Create datasets and data loaders for training and validation sets
    train_dataset_fold = TensorDataset(X_train_fold, y_train_fold)
    val_dataset_fold = TensorDataset(X_val_fold, y_val_fold)

    train_loader_fold = DataLoader(train_dataset_fold, batch_size=batch_size, shuffle=True)
    val_loader_fold = DataLoader(val_dataset_fold, batch_size=batch_size, shuffle=False)

    # Initialize model, loss function, and optimizer
    model = models.ANN_BinaryClassifier(input_size, hidden_size, output_size).to(device)
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Initialize lists to store metrics for this fold
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    
    
    # Training loop
    for epoch in range(num_epochs):
        model.train()

        total_loss = 0.0
        correct_predictions = 0
        total_samples = 0

        # Iterate over batches in the training set
        for inputs, labels in train_loader_fold:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Calculate accuracy
            predicted = (outputs > 0.5).float()
            correct_predictions += (predicted == labels).sum().item()
            total_samples += labels.size(0)

            total_loss += loss.item()

        average_loss = total_loss / len(train_loader_fold)
        accuracy = correct_predictions / total_samples
        
        # if (epoch + 1) % 5 == 0:
        print(f'Training - Epoch [{epoch + 1}/{num_epochs}], Loss: {average_loss:.4f}, Accuracy: {accuracy * 100:.2f}%')

        # Append metrics to lists
        train_losses.append(average_loss)
        train_accuracies.append(accuracy)

        # Validation loop
        model.eval()

        val_loss = 0.0
        val_correct_predictions = 0
        val_total_samples = 0

        # Disable gradient calculation during validation
        with torch.no_grad():
            # Iterate over batches in the validation set
            for val_inputs, val_labels in val_loader_fold:
                val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
                val_outputs = model(val_inputs)
                val_loss += criterion(val_outputs, val_labels).item()

                # Calculate accuracy
                val_predicted = (val_outputs > 0.5).float()
                val_correct_predictions += (val_predicted == val_labels).sum().item()
                val_total_samples += val_labels.size(0)

            val_average_loss = val_loss / len(val_loader_fold)
            val_accuracy = val_correct_predictions / val_total_samples

            print(f'Validation - Epoch [{epoch + 1}/{num_epochs}], Loss: {val_average_loss:.4f}, Accuracy: {val_accuracy * 100:.2f}%')

            # Append metrics to lists
            val_losses.append(val_average_loss)
            val_accuracies.append(val_accuracy)

    # Store metrics for this fold in the dictionary
    fold_metrics['train_loss'].append(train_losses)
    fold_metrics['val_loss'].append(val_losses)
    fold_metrics['train_accuracy'].append(train_accuracies)
    fold_metrics['val_accuracy'].append(val_accuracies)

t1 = time() # Record the ending time for K-Fold cross-validation

# Calculate and print the time taken for K-Fold cross-validation of the model
preprocessing_d["Time <K-Fold cross validation>"] = t1 - t0
print(f"Time <K-Fold cross validation>: {preprocessing_d['Time <K-Fold cross validation>']:.3f} seconds")
# Out:
# Fold 1/5
# Training - Epoch [1/50], Loss: 16.7715, Accuracy: 77.61%
# Validation - Epoch [1/50], Loss: 2.9513, Accuracy: 82.52%
# Training - Epoch [2/50], Loss: 1.9408, Accuracy: 93.10%
# Validation - Epoch [2/50], Loss: 2.3300, Accuracy: 77.68%
# Training - Epoch [3/50], Loss: 1.3330, Accuracy: 94.39%
# Validation - Epoch [3/50], Loss: 0.6325, Accuracy: 96.26%
# Training - Epoch [4/50], Loss: 0.9061, Accuracy: 95.22%
# Validation - Epoch [4/50], Loss: 0.4511, Accuracy: 96.47%
# Training - Epoch [5/50], Loss: 0.6025, Accuracy: 95.96%
# Validation - Epoch [5/50], Loss: 0.5487, Accuracy: 96.66%
# Training - Epoch [6/50], Loss: 0.4229, Accuracy: 95.46%
# Validation - Epoch [6/50], Loss: 0.2041, Accuracy: 96.75%
# Training - Epoch [7/50], Loss: 0.2661, Accuracy: 94.26%
# Validation - Epoch [7/50], Loss: 0.1876, Accuracy: 94.90%
# Training - Epoch [8/50], Loss: 0.2258, Accuracy: 94.26%
# Validation - Epoch [8/50], Loss: 0.1668, Accuracy: 95.56%
# Training - Epoch [9/50], Loss: 0.1838, Accuracy: 95.21%
# Validation - Epoch [9/50], Loss: 0.6791, Accuracy: 75.58%
# Training - Epoch [10/50], Loss: 0.2052, Accuracy: 95.26%
# Validation - Epoch [10/50], Loss: 0.1387, Accuracy: 96.68%
# Training - Epoch [11/50], Loss: 0.1774, Accuracy: 95.69%
# Validation - Epoch [11/50], Loss: 0.1839, Accuracy: 95.01%
# Training - Epoch [12/50], Loss: 0.1872, Accuracy: 95.68%
# Validation - Epoch [12/50], Loss: 0.1423, Accuracy: 96.53%
# Training - Epoch [13/50], Loss: 0.1858, Accuracy: 95.90%
# Validation - Epoch [13/50], Loss: 0.1448, Accuracy: 96.44%
# Training - Epoch [14/50], Loss: 0.1954, Accuracy: 95.92%
# Validation - Epoch [14/50], Loss: 0.5104, Accuracy: 96.22%
# Training - Epoch [15/50], Loss: 0.2215, Accuracy: 96.03%
# Validation - Epoch [15/50], Loss: 0.1373, Accuracy: 96.71%
# Training - Epoch [16/50], Loss: 0.1610, Accuracy: 95.95%
# Validation - Epoch [16/50], Loss: 0.1418, Accuracy: 96.18%
# Training - Epoch [17/50], Loss: 0.1605, Accuracy: 96.07%
# Validation - Epoch [17/50], Loss: 0.1380, Accuracy: 96.64%
# Training - Epoch [18/50], Loss: 0.2062, Accuracy: 96.09%
# Validation - Epoch [18/50], Loss: 0.1607, Accuracy: 95.50%
# Training - Epoch [19/50], Loss: 0.1965, Accuracy: 96.19%
# Validation - Epoch [19/50], Loss: 0.1359, Accuracy: 96.75%
# Training - Epoch [20/50], Loss: 0.1752, Accuracy: 96.15%
# Validation - Epoch [20/50], Loss: 0.1408, Accuracy: 96.59%
# Training - Epoch [21/50], Loss: 0.2769, Accuracy: 96.08%
# Validation - Epoch [21/50], Loss: 0.1374, Accuracy: 96.70%
# Training - Epoch [22/50], Loss: 0.2086, Accuracy: 96.25%
# Validation - Epoch [22/50], Loss: 0.1509, Accuracy: 96.14%
# Training - Epoch [23/50], Loss: 0.1662, Accuracy: 96.16%
# Validation - Epoch [23/50], Loss: 0.1649, Accuracy: 96.67%
# Training - Epoch [24/50], Loss: 0.1626, Accuracy: 96.38%
# Validation - Epoch [24/50], Loss: 0.1346, Accuracy: 96.78%
# Training - Epoch [25/50], Loss: 0.1570, Accuracy: 96.34%
# Validation - Epoch [25/50], Loss: 0.1490, Accuracy: 96.30%
# Training - Epoch [26/50], Loss: 0.1580, Accuracy: 96.40%
# Validation - Epoch [26/50], Loss: 0.1492, Accuracy: 96.31%
# Training - Epoch [27/50], Loss: 0.1608, Accuracy: 96.43%
# Validation - Epoch [27/50], Loss: 0.1365, Accuracy: 96.74%
# Training - Epoch [28/50], Loss: 0.2009, Accuracy: 96.39%
# Validation - Epoch [28/50], Loss: 0.1494, Accuracy: 96.29%
# Training - Epoch [29/50], Loss: 0.1592, Accuracy: 96.42%
# Validation - Epoch [29/50], Loss: 0.1333, Accuracy: 96.76%
# Training - Epoch [30/50], Loss: 0.1459, Accuracy: 96.45%
# Validation - Epoch [30/50], Loss: 0.1385, Accuracy: 96.65%
# Training - Epoch [31/50], Loss: 0.1825, Accuracy: 96.38%
# Validation - Epoch [31/50], Loss: 0.1338, Accuracy: 96.79%
# Training - Epoch [32/50], Loss: 0.1453, Accuracy: 96.57%
# Validation - Epoch [32/50], Loss: 0.1334, Accuracy: 96.30%
# Training - Epoch [33/50], Loss: 0.2047, Accuracy: 96.43%
# Validation - Epoch [33/50], Loss: 0.1398, Accuracy: 96.60%
# Training - Epoch [34/50], Loss: 0.2301, Accuracy: 96.52%
# Validation - Epoch [34/50], Loss: 0.1209, Accuracy: 96.79%
# Training - Epoch [35/50], Loss: 0.1355, Accuracy: 96.63%
# Validation - Epoch [35/50], Loss: 0.1410, Accuracy: 96.64%
# Training - Epoch [36/50], Loss: 0.2106, Accuracy: 96.63%
# Validation - Epoch [36/50], Loss: 0.0992, Accuracy: 97.45%
# Training - Epoch [37/50], Loss: 0.1205, Accuracy: 97.36%
# Validation - Epoch [37/50], Loss: 0.0637, Accuracy: 98.56%
# Training - Epoch [38/50], Loss: 0.1476, Accuracy: 97.58%
# Validation - Epoch [38/50], Loss: 0.1014, Accuracy: 97.03%
# Training - Epoch [39/50], Loss: 0.1409, Accuracy: 97.76%
# Validation - Epoch [39/50], Loss: 0.4516, Accuracy: 97.27%
# Training - Epoch [40/50], Loss: 0.1027, Accuracy: 97.78%
# Validation - Epoch [40/50], Loss: 0.0619, Accuracy: 98.38%
# Training - Epoch [41/50], Loss: 0.4228, Accuracy: 97.56%
# Validation - Epoch [41/50], Loss: 0.0738, Accuracy: 98.11%
# Training - Epoch [42/50], Loss: 0.0782, Accuracy: 98.04%
# Validation - Epoch [42/50], Loss: 0.0625, Accuracy: 98.35%
# Training - Epoch [43/50], Loss: 0.0809, Accuracy: 98.04%
# Validation - Epoch [43/50], Loss: 0.1161, Accuracy: 96.84%
# Training - Epoch [44/50], Loss: 0.1291, Accuracy: 98.08%
# Validation - Epoch [44/50], Loss: 0.0653, Accuracy: 97.48%
# Training - Epoch [45/50], Loss: 0.1933, Accuracy: 98.07%
# Validation - Epoch [45/50], Loss: 0.0610, Accuracy: 98.39%
# Training - Epoch [46/50], Loss: 0.0866, Accuracy: 98.12%
# Validation - Epoch [46/50], Loss: 0.1527, Accuracy: 96.75%
# Training - Epoch [47/50], Loss: 0.0952, Accuracy: 98.17%
# Validation - Epoch [47/50], Loss: 0.0722, Accuracy: 98.40%
# Training - Epoch [48/50], Loss: 0.0952, Accuracy: 98.25%
# Validation - Epoch [48/50], Loss: 0.0653, Accuracy: 98.25%
# Training - Epoch [49/50], Loss: 0.0736, Accuracy: 98.24%
# Validation - Epoch [49/50], Loss: 0.0829, Accuracy: 97.85%
# Training - Epoch [50/50], Loss: 0.0700, Accuracy: 98.34%
# Validation - Epoch [50/50], Loss: 0.0521, Accuracy: 98.63%
#
# Fold 2/5
# Training - Epoch [1/50], Loss: 0.9936, Accuracy: 89.53%
# Validation - Epoch [1/50], Loss: 0.2778, Accuracy: 93.00%
# Training - Epoch [2/50], Loss: 0.4024, Accuracy: 92.56%
# Validation - Epoch [2/50], Loss: 0.2490, Accuracy: 94.30%
# Training - Epoch [3/50], Loss: 0.3611, Accuracy: 93.03%
# Validation - Epoch [3/50], Loss: 0.2773, Accuracy: 88.70%
# Training - Epoch [4/50], Loss: 0.3150, Accuracy: 93.53%
# Validation - Epoch [4/50], Loss: 0.1914, Accuracy: 94.94%
# Training - Epoch [5/50], Loss: 0.2643, Accuracy: 94.13%
# Validation - Epoch [5/50], Loss: 0.1543, Accuracy: 95.42%
# Training - Epoch [6/50], Loss: 0.2486, Accuracy: 94.53%
# Validation - Epoch [6/50], Loss: 0.3715, Accuracy: 93.47%
# Training - Epoch [7/50], Loss: 0.2109, Accuracy: 95.07%
# Validation - Epoch [7/50], Loss: 0.1658, Accuracy: 95.68%
# Training - Epoch [8/50], Loss: 0.1915, Accuracy: 94.69%
# Validation - Epoch [8/50], Loss: 0.1484, Accuracy: 96.40%
# Training - Epoch [9/50], Loss: 0.1845, Accuracy: 95.02%
# Validation - Epoch [9/50], Loss: 0.1751, Accuracy: 95.29%
# Training - Epoch [10/50], Loss: 0.1938, Accuracy: 94.85%
# Validation - Epoch [10/50], Loss: 0.3002, Accuracy: 90.19%
# Training - Epoch [11/50], Loss: 0.1848, Accuracy: 95.38%
# Validation - Epoch [11/50], Loss: 0.2440, Accuracy: 90.82%
# Training - Epoch [12/50], Loss: 0.1892, Accuracy: 95.31%
# Validation - Epoch [12/50], Loss: 0.1510, Accuracy: 96.29%
# Training - Epoch [13/50], Loss: 0.1713, Accuracy: 95.57%
# Validation - Epoch [13/50], Loss: 0.1410, Accuracy: 96.64%
# Training - Epoch [14/50], Loss: 0.2040, Accuracy: 93.91%
# Validation - Epoch [14/50], Loss: 0.1503, Accuracy: 96.25%
# Training - Epoch [15/50], Loss: 0.1625, Accuracy: 95.78%
# Validation - Epoch [15/50], Loss: 0.1675, Accuracy: 95.17%
# Training - Epoch [16/50], Loss: 0.1896, Accuracy: 95.71%
# Validation - Epoch [16/50], Loss: 0.1238, Accuracy: 96.58%
# Training - Epoch [17/50], Loss: 0.1648, Accuracy: 95.88%
# Validation - Epoch [17/50], Loss: 0.1636, Accuracy: 95.39%
# Training - Epoch [18/50], Loss: 0.1584, Accuracy: 95.86%
# Validation - Epoch [18/50], Loss: 0.1602, Accuracy: 95.53%
# Training - Epoch [19/50], Loss: 0.1574, Accuracy: 95.95%
# Validation - Epoch [19/50], Loss: 0.1391, Accuracy: 96.42%
# Training - Epoch [20/50], Loss: 0.1898, Accuracy: 94.91%
# Validation - Epoch [20/50], Loss: 0.1635, Accuracy: 95.75%
# Training - Epoch [21/50], Loss: 0.1654, Accuracy: 95.99%
# Validation - Epoch [21/50], Loss: 0.1462, Accuracy: 95.86%
# Training - Epoch [22/50], Loss: 0.1868, Accuracy: 95.95%
# Validation - Epoch [22/50], Loss: 0.1414, Accuracy: 96.30%
# Training - Epoch [23/50], Loss: 0.1932, Accuracy: 96.08%
# Validation - Epoch [23/50], Loss: 0.1405, Accuracy: 96.65%
# Training - Epoch [24/50], Loss: 0.1700, Accuracy: 96.00%
# Validation - Epoch [24/50], Loss: 0.1641, Accuracy: 95.79%
# Training - Epoch [25/50], Loss: 0.1573, Accuracy: 96.15%
# Validation - Epoch [25/50], Loss: 0.1341, Accuracy: 96.89%
# Training - Epoch [26/50], Loss: 0.1464, Accuracy: 96.26%
# Validation - Epoch [26/50], Loss: 0.1431, Accuracy: 96.45%
# Training - Epoch [27/50], Loss: 0.1728, Accuracy: 96.31%
# Validation - Epoch [27/50], Loss: 0.1397, Accuracy: 96.29%
# Training - Epoch [28/50], Loss: 0.1466, Accuracy: 96.27%
# Validation - Epoch [28/50], Loss: 0.1369, Accuracy: 96.78%
# Training - Epoch [29/50], Loss: 0.1558, Accuracy: 96.35%
# Validation - Epoch [29/50], Loss: 0.1012, Accuracy: 97.34%
# Training - Epoch [30/50], Loss: 0.1617, Accuracy: 96.33%
# Validation - Epoch [30/50], Loss: 0.1129, Accuracy: 96.93%
# Training - Epoch [31/50], Loss: 0.1480, Accuracy: 96.41%
# Validation - Epoch [31/50], Loss: 0.1492, Accuracy: 96.21%
# Training - Epoch [32/50], Loss: 0.1430, Accuracy: 96.65%
# Validation - Epoch [32/50], Loss: 0.1421, Accuracy: 96.57%
# Training - Epoch [33/50], Loss: 0.1603, Accuracy: 96.50%
# Validation - Epoch [33/50], Loss: 0.1269, Accuracy: 97.20%
# Training - Epoch [34/50], Loss: 0.1546, Accuracy: 96.56%
# Validation - Epoch [34/50], Loss: 0.1179, Accuracy: 97.31%
# Training - Epoch [35/50], Loss: 0.1553, Accuracy: 96.65%
# Validation - Epoch [35/50], Loss: 0.1321, Accuracy: 96.90%
# Training - Epoch [36/50], Loss: 0.1677, Accuracy: 96.73%
# Validation - Epoch [36/50], Loss: 0.1220, Accuracy: 96.80%
# Training - Epoch [37/50], Loss: 0.1415, Accuracy: 96.67%
# Validation - Epoch [37/50], Loss: 0.1198, Accuracy: 97.36%
# Training - Epoch [38/50], Loss: 0.1297, Accuracy: 96.81%
# Validation - Epoch [38/50], Loss: 0.1307, Accuracy: 96.83%
# Training - Epoch [39/50], Loss: 0.1311, Accuracy: 96.96%
# Validation - Epoch [39/50], Loss: 0.1149, Accuracy: 97.01%
# Training - Epoch [40/50], Loss: 0.1562, Accuracy: 96.89%
# Validation - Epoch [40/50], Loss: 0.1049, Accuracy: 98.34%
# Training - Epoch [41/50], Loss: 0.1344, Accuracy: 96.97%
# Validation - Epoch [41/50], Loss: 0.1250, Accuracy: 97.02%
# Training - Epoch [42/50], Loss: 0.1386, Accuracy: 96.90%
# Validation - Epoch [42/50], Loss: 0.0904, Accuracy: 97.93%
# Training - Epoch [43/50], Loss: 0.1516, Accuracy: 96.91%
# Validation - Epoch [43/50], Loss: 0.1295, Accuracy: 96.44%
# Training - Epoch [44/50], Loss: 0.1340, Accuracy: 96.87%
# Validation - Epoch [44/50], Loss: 0.0983, Accuracy: 96.91%
# Training - Epoch [45/50], Loss: 0.1440, Accuracy: 97.08%
# Validation - Epoch [45/50], Loss: 0.1382, Accuracy: 96.46%
# Training - Epoch [46/50], Loss: 0.1571, Accuracy: 96.96%
# Validation - Epoch [46/50], Loss: 0.1261, Accuracy: 96.73%
# Training - Epoch [47/50], Loss: 0.1256, Accuracy: 97.08%
# Validation - Epoch [47/50], Loss: 0.0819, Accuracy: 98.09%
# Training - Epoch [48/50], Loss: 0.1300, Accuracy: 97.30%
# Validation - Epoch [48/50], Loss: 0.1542, Accuracy: 95.32%
# Training - Epoch [49/50], Loss: 0.1306, Accuracy: 97.10%
# Validation - Epoch [49/50], Loss: 0.1148, Accuracy: 96.82%
# Training - Epoch [50/50], Loss: 0.1186, Accuracy: 97.12%
# Validation - Epoch [50/50], Loss: 0.1199, Accuracy: 96.71%
#
# Fold 3/5
# Training - Epoch [1/50], Loss: 32.3071, Accuracy: 63.88%
# Validation - Epoch [1/50], Loss: 1.8243, Accuracy: 92.06%
# Training - Epoch [2/50], Loss: 0.7261, Accuracy: 92.48%
# Validation - Epoch [2/50], Loss: 0.7872, Accuracy: 92.16%
# Training - Epoch [3/50], Loss: 0.7410, Accuracy: 94.01%
# Validation - Epoch [3/50], Loss: 0.2439, Accuracy: 96.66%
# Training - Epoch [4/50], Loss: 0.7098, Accuracy: 94.61%
# Validation - Epoch [4/50], Loss: 0.3912, Accuracy: 96.84%
# Training - Epoch [5/50], Loss: 0.6991, Accuracy: 95.10%
# Validation - Epoch [5/50], Loss: 0.3203, Accuracy: 96.41%
# Training - Epoch [6/50], Loss: 0.6399, Accuracy: 95.51%
# Validation - Epoch [6/50], Loss: 0.2013, Accuracy: 96.88%
# Training - Epoch [7/50], Loss: 0.5623, Accuracy: 96.12%
# Validation - Epoch [7/50], Loss: 0.2244, Accuracy: 96.96%
# Training - Epoch [8/50], Loss: 0.4962, Accuracy: 96.51%
# Validation - Epoch [8/50], Loss: 0.2931, Accuracy: 96.53%
# Training - Epoch [9/50], Loss: 0.3547, Accuracy: 96.06%
# Validation - Epoch [9/50], Loss: 0.6393, Accuracy: 92.28%
# Training - Epoch [10/50], Loss: 0.1784, Accuracy: 95.65%
# Validation - Epoch [10/50], Loss: 0.1327, Accuracy: 96.65%
# Training - Epoch [11/50], Loss: 0.1738, Accuracy: 95.77%
# Validation - Epoch [11/50], Loss: 0.1325, Accuracy: 96.25%
# Training - Epoch [12/50], Loss: 0.1827, Accuracy: 95.75%
# Validation - Epoch [12/50], Loss: 0.1399, Accuracy: 96.51%
# Training - Epoch [13/50], Loss: 0.1774, Accuracy: 95.64%
# Validation - Epoch [13/50], Loss: 0.1464, Accuracy: 96.35%
# Training - Epoch [14/50], Loss: 0.1591, Accuracy: 95.92%
# Validation - Epoch [14/50], Loss: 0.1685, Accuracy: 95.16%
# Training - Epoch [15/50], Loss: 0.1691, Accuracy: 95.90%
# Validation - Epoch [15/50], Loss: 0.1342, Accuracy: 96.64%
# Training - Epoch [16/50], Loss: 0.1892, Accuracy: 95.93%
# Validation - Epoch [16/50], Loss: 0.1338, Accuracy: 96.90%
# Training - Epoch [17/50], Loss: 0.1776, Accuracy: 95.94%
# Validation - Epoch [17/50], Loss: 0.1307, Accuracy: 96.72%
# Training - Epoch [18/50], Loss: 0.1784, Accuracy: 95.92%
# Validation - Epoch [18/50], Loss: 0.1416, Accuracy: 96.62%
# Training - Epoch [19/50], Loss: 0.1685, Accuracy: 96.00%
# Validation - Epoch [19/50], Loss: 0.1429, Accuracy: 96.58%
# Training - Epoch [20/50], Loss: 0.1590, Accuracy: 96.23%
# Validation - Epoch [20/50], Loss: 0.1349, Accuracy: 96.61%
# Training - Epoch [21/50], Loss: 0.1589, Accuracy: 96.14%
# Validation - Epoch [21/50], Loss: 0.1257, Accuracy: 96.82%
# Training - Epoch [22/50], Loss: 0.1883, Accuracy: 96.21%
# Validation - Epoch [22/50], Loss: 0.1292, Accuracy: 97.02%
# Training - Epoch [23/50], Loss: 0.1637, Accuracy: 96.34%
# Validation - Epoch [23/50], Loss: 0.1348, Accuracy: 95.97%
# Training - Epoch [24/50], Loss: 0.1686, Accuracy: 96.36%
# Validation - Epoch [24/50], Loss: 0.1356, Accuracy: 96.30%
# Training - Epoch [25/50], Loss: 0.1584, Accuracy: 96.40%
# Validation - Epoch [25/50], Loss: 0.1072, Accuracy: 97.81%
# Training - Epoch [26/50], Loss: 0.1529, Accuracy: 96.36%
# Validation - Epoch [26/50], Loss: 0.1359, Accuracy: 95.99%
# Training - Epoch [27/50], Loss: 0.1618, Accuracy: 96.51%
# Validation - Epoch [27/50], Loss: 0.1246, Accuracy: 96.64%
# Training - Epoch [28/50], Loss: 0.1616, Accuracy: 96.55%
# Validation - Epoch [28/50], Loss: 0.1141, Accuracy: 97.11%
# Training - Epoch [29/50], Loss: 0.1747, Accuracy: 96.63%
# Validation - Epoch [29/50], Loss: 0.0842, Accuracy: 98.21%
# Training - Epoch [30/50], Loss: 0.1553, Accuracy: 96.58%
# Validation - Epoch [30/50], Loss: 0.1190, Accuracy: 96.96%
# Training - Epoch [31/50], Loss: 0.1502, Accuracy: 96.67%
# Validation - Epoch [31/50], Loss: 0.1124, Accuracy: 97.12%
# Training - Epoch [32/50], Loss: 0.1539, Accuracy: 96.69%
# Validation - Epoch [32/50], Loss: 0.1343, Accuracy: 96.46%
# Training - Epoch [33/50], Loss: 0.1430, Accuracy: 96.82%
# Validation - Epoch [33/50], Loss: 0.1138, Accuracy: 97.04%
# Training - Epoch [34/50], Loss: 0.1478, Accuracy: 96.72%
# Validation - Epoch [34/50], Loss: 0.1261, Accuracy: 96.53%
# Training - Epoch [35/50], Loss: 0.1505, Accuracy: 96.74%
# Validation - Epoch [35/50], Loss: 0.1192, Accuracy: 96.81%
# Training - Epoch [36/50], Loss: 0.1739, Accuracy: 96.79%
# Validation - Epoch [36/50], Loss: 0.1159, Accuracy: 96.80%
# Training - Epoch [37/50], Loss: 0.1290, Accuracy: 96.86%
# Validation - Epoch [37/50], Loss: 0.1117, Accuracy: 97.01%
# Training - Epoch [38/50], Loss: 0.1457, Accuracy: 96.91%
# Validation - Epoch [38/50], Loss: 0.1275, Accuracy: 96.46%
# Training - Epoch [39/50], Loss: 0.1374, Accuracy: 97.14%
# Validation - Epoch [39/50], Loss: 0.0770, Accuracy: 98.35%
# Training - Epoch [40/50], Loss: 0.1569, Accuracy: 97.08%
# Validation - Epoch [40/50], Loss: 0.1088, Accuracy: 97.36%
# Training - Epoch [41/50], Loss: 0.1203, Accuracy: 96.98%
# Validation - Epoch [41/50], Loss: 0.1128, Accuracy: 96.93%
# Training - Epoch [42/50], Loss: 0.1260, Accuracy: 97.07%
# Validation - Epoch [42/50], Loss: 0.0997, Accuracy: 97.96%
# Training - Epoch [43/50], Loss: 0.1258, Accuracy: 97.04%
# Validation - Epoch [43/50], Loss: 0.0764, Accuracy: 98.35%
# Training - Epoch [44/50], Loss: 0.1300, Accuracy: 97.07%
# Validation - Epoch [44/50], Loss: 0.1054, Accuracy: 97.31%
# Training - Epoch [45/50], Loss: 0.1275, Accuracy: 97.06%
# Validation - Epoch [45/50], Loss: 0.0896, Accuracy: 97.82%
# Training - Epoch [46/50], Loss: 0.1292, Accuracy: 97.20%
# Validation - Epoch [46/50], Loss: 0.0908, Accuracy: 97.65%
# Training - Epoch [47/50], Loss: 0.1242, Accuracy: 97.17%
# Validation - Epoch [47/50], Loss: 0.1126, Accuracy: 97.06%
# Training - Epoch [48/50], Loss: 0.1112, Accuracy: 97.31%
# Validation - Epoch [48/50], Loss: 0.0959, Accuracy: 97.14%
# Training - Epoch [49/50], Loss: 0.1158, Accuracy: 97.29%
# Validation - Epoch [49/50], Loss: 0.1247, Accuracy: 96.47%
# Training - Epoch [50/50], Loss: 0.1264, Accuracy: 97.29%
# Validation - Epoch [50/50], Loss: 0.1091, Accuracy: 97.19%
#
# Fold 4/5
# Training - Epoch [1/50], Loss: 1.5943, Accuracy: 91.56%
# Validation - Epoch [1/50], Loss: 0.2611, Accuracy: 96.23%
# Training - Epoch [2/50], Loss: 0.3123, Accuracy: 95.14%
# Validation - Epoch [2/50], Loss: 0.1695, Accuracy: 96.68%
# Training - Epoch [3/50], Loss: 0.2329, Accuracy: 95.68%
# Validation - Epoch [3/50], Loss: 0.2066, Accuracy: 94.71%
# Training - Epoch [4/50], Loss: 0.1978, Accuracy: 94.84%
# Validation - Epoch [4/50], Loss: 0.1888, Accuracy: 94.75%
# Training - Epoch [5/50], Loss: 0.2011, Accuracy: 94.72%
# Validation - Epoch [5/50], Loss: 0.7822, Accuracy: 90.63%
# Training - Epoch [6/50], Loss: 0.1988, Accuracy: 95.26%
# Validation - Epoch [6/50], Loss: 0.1571, Accuracy: 95.97%
# Training - Epoch [7/50], Loss: 0.1830, Accuracy: 95.27%
# Validation - Epoch [7/50], Loss: 0.1443, Accuracy: 96.36%
# Training - Epoch [8/50], Loss: 0.1774, Accuracy: 95.45%
# Validation - Epoch [8/50], Loss: 0.1296, Accuracy: 97.04%
# Training - Epoch [9/50], Loss: 0.1669, Accuracy: 95.72%
# Validation - Epoch [9/50], Loss: 0.1527, Accuracy: 96.22%
# Training - Epoch [10/50], Loss: 0.1690, Accuracy: 95.86%
# Validation - Epoch [10/50], Loss: 0.1489, Accuracy: 96.34%
# Training - Epoch [11/50], Loss: 0.1743, Accuracy: 95.90%
# Validation - Epoch [11/50], Loss: 0.1494, Accuracy: 96.34%
# Training - Epoch [12/50], Loss: 0.1603, Accuracy: 96.04%
# Validation - Epoch [12/50], Loss: 0.1546, Accuracy: 95.98%
# Training - Epoch [13/50], Loss: 0.1676, Accuracy: 95.97%
# Validation - Epoch [13/50], Loss: 0.1366, Accuracy: 97.11%
# Training - Epoch [14/50], Loss: 0.1690, Accuracy: 96.12%
# Validation - Epoch [14/50], Loss: 0.1301, Accuracy: 97.16%
# Training - Epoch [15/50], Loss: 0.1936, Accuracy: 96.20%
# Validation - Epoch [15/50], Loss: 0.1373, Accuracy: 96.53%
# Training - Epoch [16/50], Loss: 0.1790, Accuracy: 96.03%
# Validation - Epoch [16/50], Loss: 0.1368, Accuracy: 96.75%
# Training - Epoch [17/50], Loss: 0.1646, Accuracy: 96.21%
# Validation - Epoch [17/50], Loss: 0.1494, Accuracy: 96.07%
# Training - Epoch [18/50], Loss: 0.1472, Accuracy: 96.31%
# Validation - Epoch [18/50], Loss: 0.1501, Accuracy: 96.32%
# Training - Epoch [19/50], Loss: 0.1953, Accuracy: 96.29%
# Validation - Epoch [19/50], Loss: 0.1367, Accuracy: 96.34%
# Training - Epoch [20/50], Loss: 0.2516, Accuracy: 96.21%
# Validation - Epoch [20/50], Loss: 0.1373, Accuracy: 96.76%
# Training - Epoch [21/50], Loss: 0.1590, Accuracy: 96.34%
# Validation - Epoch [21/50], Loss: 0.1618, Accuracy: 95.48%
# Training - Epoch [22/50], Loss: 0.1909, Accuracy: 96.22%
# Validation - Epoch [22/50], Loss: 0.1407, Accuracy: 96.60%
# Training - Epoch [23/50], Loss: 0.1479, Accuracy: 96.35%
# Validation - Epoch [23/50], Loss: 0.1489, Accuracy: 97.20%
# Training - Epoch [24/50], Loss: 0.1501, Accuracy: 96.39%
# Validation - Epoch [24/50], Loss: 0.1305, Accuracy: 96.83%
# Training - Epoch [25/50], Loss: 0.1470, Accuracy: 96.47%
# Validation - Epoch [25/50], Loss: 0.1439, Accuracy: 96.54%
# Training - Epoch [26/50], Loss: 0.1592, Accuracy: 96.44%
# Validation - Epoch [26/50], Loss: 0.1411, Accuracy: 96.24%
# Training - Epoch [27/50], Loss: 0.1572, Accuracy: 96.41%
# Validation - Epoch [27/50], Loss: 0.1184, Accuracy: 96.88%
# Training - Epoch [28/50], Loss: 0.1537, Accuracy: 96.49%
# Validation - Epoch [28/50], Loss: 0.1272, Accuracy: 96.54%
# Training - Epoch [29/50], Loss: 0.1566, Accuracy: 96.45%
# Validation - Epoch [29/50], Loss: 2.0994, Accuracy: 95.51%
# Training - Epoch [30/50], Loss: 0.1550, Accuracy: 96.48%
# Validation - Epoch [30/50], Loss: 0.1374, Accuracy: 96.42%
# Training - Epoch [31/50], Loss: 0.1410, Accuracy: 96.54%
# Validation - Epoch [31/50], Loss: 0.1303, Accuracy: 96.46%
# Training - Epoch [32/50], Loss: 0.1328, Accuracy: 96.57%
# Validation - Epoch [32/50], Loss: 0.1229, Accuracy: 96.71%
# Training - Epoch [33/50], Loss: 0.1318, Accuracy: 96.62%
# Validation - Epoch [33/50], Loss: 0.1217, Accuracy: 96.72%
# Training - Epoch [34/50], Loss: 0.1353, Accuracy: 96.57%
# Validation - Epoch [34/50], Loss: 0.1372, Accuracy: 96.41%
# Training - Epoch [35/50], Loss: 0.1356, Accuracy: 96.67%
# Validation - Epoch [35/50], Loss: 0.1363, Accuracy: 96.79%
# Training - Epoch [36/50], Loss: 0.1269, Accuracy: 96.76%
# Validation - Epoch [36/50], Loss: 0.1256, Accuracy: 96.47%
# Training - Epoch [37/50], Loss: 0.1396, Accuracy: 96.76%
# Validation - Epoch [37/50], Loss: 0.1137, Accuracy: 97.01%
# Training - Epoch [38/50], Loss: 0.1372, Accuracy: 96.87%
# Validation - Epoch [38/50], Loss: 0.1181, Accuracy: 96.87%
# Training - Epoch [39/50], Loss: 0.1722, Accuracy: 96.96%
# Validation - Epoch [39/50], Loss: 0.0838, Accuracy: 97.65%
# Training - Epoch [40/50], Loss: 0.0888, Accuracy: 97.76%
# Validation - Epoch [40/50], Loss: 0.0804, Accuracy: 97.76%
# Training - Epoch [41/50], Loss: 0.0920, Accuracy: 97.83%
# Validation - Epoch [41/50], Loss: 0.0821, Accuracy: 97.74%
# Training - Epoch [42/50], Loss: 0.0814, Accuracy: 97.95%
# Validation - Epoch [42/50], Loss: 0.1064, Accuracy: 97.46%
# Training - Epoch [43/50], Loss: 0.0779, Accuracy: 98.01%
# Validation - Epoch [43/50], Loss: 0.0673, Accuracy: 98.32%
# Training - Epoch [44/50], Loss: 0.0793, Accuracy: 98.07%
# Validation - Epoch [44/50], Loss: 0.0575, Accuracy: 98.69%
# Training - Epoch [45/50], Loss: 0.0757, Accuracy: 98.08%
# Validation - Epoch [45/50], Loss: 0.0594, Accuracy: 97.77%
# Training - Epoch [46/50], Loss: 0.0732, Accuracy: 98.16%
# Validation - Epoch [46/50], Loss: 0.0585, Accuracy: 98.71%
# Training - Epoch [47/50], Loss: 0.0746, Accuracy: 98.19%
# Validation - Epoch [47/50], Loss: 0.0589, Accuracy: 98.69%
# Training - Epoch [48/50], Loss: 0.0713, Accuracy: 98.21%
# Validation - Epoch [48/50], Loss: 0.0641, Accuracy: 97.57%
# Training - Epoch [49/50], Loss: 0.0723, Accuracy: 98.19%
# Validation - Epoch [49/50], Loss: 0.0487, Accuracy: 98.76%
# Training - Epoch [50/50], Loss: 0.0725, Accuracy: 98.25%
# Validation - Epoch [50/50], Loss: 0.0675, Accuracy: 97.56%
#
# Fold 5/5
# Training - Epoch [1/50], Loss: 1.4217, Accuracy: 89.03%
# Validation - Epoch [1/50], Loss: 1.0475, Accuracy: 77.57%
# Training - Epoch [2/50], Loss: 0.3252, Accuracy: 92.76%
# Validation - Epoch [2/50], Loss: 0.2506, Accuracy: 94.21%
# Training - Epoch [3/50], Loss: 0.2984, Accuracy: 93.21%
# Validation - Epoch [3/50], Loss: 0.6288, Accuracy: 79.14%
# Training - Epoch [4/50], Loss: 0.2477, Accuracy: 93.83%
# Validation - Epoch [4/50], Loss: 0.2789, Accuracy: 94.00%
# Training - Epoch [5/50], Loss: 0.2819, Accuracy: 94.89%
# Validation - Epoch [5/50], Loss: 0.1395, Accuracy: 95.84%
# Training - Epoch [6/50], Loss: 0.2431, Accuracy: 94.34%
# Validation - Epoch [6/50], Loss: 0.1742, Accuracy: 95.40%
# Training - Epoch [7/50], Loss: 0.2298, Accuracy: 94.13%
# Validation - Epoch [7/50], Loss: 0.1616, Accuracy: 95.93%
# Training - Epoch [8/50], Loss: 0.2723, Accuracy: 90.73%
# Validation - Epoch [8/50], Loss: 0.1498, Accuracy: 96.31%
# Training - Epoch [9/50], Loss: 0.2079, Accuracy: 94.30%
# Validation - Epoch [9/50], Loss: 0.1557, Accuracy: 95.85%
# Training - Epoch [10/50], Loss: 0.2264, Accuracy: 93.34%
# Validation - Epoch [10/50], Loss: 0.7380, Accuracy: 63.10%
# Training - Epoch [11/50], Loss: 0.1999, Accuracy: 95.09%
# Validation - Epoch [11/50], Loss: 0.1814, Accuracy: 95.14%
# Training - Epoch [12/50], Loss: 0.2184, Accuracy: 94.68%
# Validation - Epoch [12/50], Loss: 0.1497, Accuracy: 96.37%
# Training - Epoch [13/50], Loss: 0.1925, Accuracy: 95.25%
# Validation - Epoch [13/50], Loss: 0.1523, Accuracy: 96.19%
# Training - Epoch [14/50], Loss: 0.2055, Accuracy: 94.59%
# Validation - Epoch [14/50], Loss: 0.1426, Accuracy: 96.48%
# Training - Epoch [15/50], Loss: 0.1860, Accuracy: 94.88%
# Validation - Epoch [15/50], Loss: 0.5043, Accuracy: 82.02%
# Training - Epoch [16/50], Loss: 0.2243, Accuracy: 95.67%
# Validation - Epoch [16/50], Loss: 0.1826, Accuracy: 95.16%
# Training - Epoch [17/50], Loss: 0.1653, Accuracy: 95.67%
# Validation - Epoch [17/50], Loss: 0.1703, Accuracy: 95.62%
# Training - Epoch [18/50], Loss: 0.1754, Accuracy: 95.80%
# Validation - Epoch [18/50], Loss: 0.1322, Accuracy: 97.08%
# Training - Epoch [19/50], Loss: 0.1672, Accuracy: 95.68%
# Validation - Epoch [19/50], Loss: 0.1525, Accuracy: 96.24%
# Training - Epoch [20/50], Loss: 0.1677, Accuracy: 95.93%
# Validation - Epoch [20/50], Loss: 0.1568, Accuracy: 96.08%
# Training - Epoch [21/50], Loss: 0.1776, Accuracy: 95.68%
# Validation - Epoch [21/50], Loss: 0.1457, Accuracy: 96.47%
# Training - Epoch [22/50], Loss: 0.1594, Accuracy: 96.02%
# Validation - Epoch [22/50], Loss: 0.1476, Accuracy: 97.23%
# Training - Epoch [23/50], Loss: 0.1559, Accuracy: 96.04%
# Validation - Epoch [23/50], Loss: 0.1439, Accuracy: 96.05%
# Training - Epoch [24/50], Loss: 0.1586, Accuracy: 95.92%
# Validation - Epoch [24/50], Loss: 0.1339, Accuracy: 96.77%
# Training - Epoch [25/50], Loss: 0.2088, Accuracy: 95.95%
# Validation - Epoch [25/50], Loss: 2.7427, Accuracy: 95.05%
# Training - Epoch [26/50], Loss: 0.2056, Accuracy: 96.04%
# Validation - Epoch [26/50], Loss: 0.1335, Accuracy: 96.88%
# Training - Epoch [27/50], Loss: 0.1520, Accuracy: 96.14%
# Validation - Epoch [27/50], Loss: 0.1317, Accuracy: 96.97%
# Training - Epoch [28/50], Loss: 0.1904, Accuracy: 96.01%
# Validation - Epoch [28/50], Loss: 0.1626, Accuracy: 95.87%
# Training - Epoch [29/50], Loss: 0.1722, Accuracy: 96.28%
# Validation - Epoch [29/50], Loss: 0.1261, Accuracy: 97.35%
# Training - Epoch [30/50], Loss: 0.1701, Accuracy: 96.18%
# Validation - Epoch [30/50], Loss: 0.1111, Accuracy: 96.88%
# Training - Epoch [31/50], Loss: 0.1553, Accuracy: 96.31%
# Validation - Epoch [31/50], Loss: 0.1388, Accuracy: 96.68%
# Training - Epoch [32/50], Loss: 0.1596, Accuracy: 96.29%
# Validation - Epoch [32/50], Loss: 0.1342, Accuracy: 96.84%
# Training - Epoch [33/50], Loss: 0.2081, Accuracy: 96.38%
# Validation - Epoch [33/50], Loss: 0.1510, Accuracy: 96.12%
# Training - Epoch [34/50], Loss: 0.1472, Accuracy: 96.38%
# Validation - Epoch [34/50], Loss: 0.1506, Accuracy: 96.28%
# Training - Epoch [35/50], Loss: 0.1723, Accuracy: 96.45%
# Validation - Epoch [35/50], Loss: 0.1010, Accuracy: 97.45%
# Training - Epoch [36/50], Loss: 0.1643, Accuracy: 96.54%
# Validation - Epoch [36/50], Loss: 0.1287, Accuracy: 97.11%
# Training - Epoch [37/50], Loss: 0.1382, Accuracy: 96.53%
# Validation - Epoch [37/50], Loss: 0.1036, Accuracy: 97.25%
# Training - Epoch [38/50], Loss: 0.1407, Accuracy: 96.64%
# Validation - Epoch [38/50], Loss: 0.1098, Accuracy: 96.93%
# Training - Epoch [39/50], Loss: 0.1435, Accuracy: 96.66%
# Validation - Epoch [39/50], Loss: 0.1314, Accuracy: 96.90%
# Training - Epoch [40/50], Loss: 0.1335, Accuracy: 96.78%
# Validation - Epoch [40/50], Loss: 0.1219, Accuracy: 97.17%
# Training - Epoch [41/50], Loss: 0.1463, Accuracy: 96.77%
# Validation - Epoch [41/50], Loss: 0.1078, Accuracy: 97.35%
# Training - Epoch [42/50], Loss: 0.1410, Accuracy: 96.86%
# Validation - Epoch [42/50], Loss: 0.1261, Accuracy: 96.17%
# Training - Epoch [43/50], Loss: 0.1390, Accuracy: 97.02%
# Validation - Epoch [43/50], Loss: 0.1166, Accuracy: 96.91%
# Training - Epoch [44/50], Loss: 0.1390, Accuracy: 96.90%
# Validation - Epoch [44/50], Loss: 0.0832, Accuracy: 98.11%
# Training - Epoch [45/50], Loss: 0.1555, Accuracy: 96.86%
# Validation - Epoch [45/50], Loss: 0.1117, Accuracy: 97.16%
# Training - Epoch [46/50], Loss: 0.1230, Accuracy: 97.10%
# Validation - Epoch [46/50], Loss: 0.0743, Accuracy: 98.66%
# Training - Epoch [47/50], Loss: 0.1601, Accuracy: 96.82%
# Validation - Epoch [47/50], Loss: 0.1103, Accuracy: 97.16%
# Training - Epoch [48/50], Loss: 0.1581, Accuracy: 96.93%
# Validation - Epoch [48/50], Loss: 0.1135, Accuracy: 97.13%
# Training - Epoch [49/50], Loss: 0.1384, Accuracy: 97.01%
# Validation - Epoch [49/50], Loss: 0.0770, Accuracy: 98.32%
# Training - Epoch [50/50], Loss: 0.1195, Accuracy: 96.92%
# Validation - Epoch [50/50], Loss: 0.1333, Accuracy: 96.55%
# Time <K-Fold cross validation>: 3945.591 seconds

# %%
# Call the function to plot K-folds metrics
nn_utils.plot_folds_train_val_metrics(fold_metrics['train_loss'], fold_metrics['val_loss'], fold_metrics['train_accuracy'], fold_metrics['val_accuracy'], num_epochs)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Processing times for various preprocessing steps involved in the data preparation and model training pipeline

# %%
# Print the preprocessing times
print("Time Report:")
for key, time in preprocessing_d.items():
    print(f"{key}: {time:.4f} seconds")
